# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### You are the business owner of the retail firm and want to see how your company is performing. You are interested in finding out the weak areas where you can work to make more profit. What all business problems you can derive by looking into the data.

# %%
#importing  essential libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\Gavas\Desktop\SampleSuperstore.csv")

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#Checking if any duplicate row is there in the dataset
data.duplicated().sum()
# Out:
# 17

# %%
#Removing Duplicates
data.drop_duplicates(inplace=True)

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %%
data.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023476  0.013110  0.059225 -0.029892
# Sales          -0.023476  1.000000  0.200722 -0.028311  0.479067
# Quantity        0.013110  0.200722  1.000000  0.008678  0.066211
# Discount        0.059225 -0.028311  0.008678  1.000000 -0.219662
# Profit         -0.029892  0.479067  0.066211 -0.219662  1.000000

# %%
#removing the unimportant columns
data=data.drop(['Country', 'Postal Code'], axis=1)

# %%
#Checking correlation between columns visually
plt.figure(figsize = (12,8))
sns.heatmap(data.corr(),annot = True,cmap = 'BrBG')

# %%
data
# Out:
#            Ship Mode    Segment             City       State Region  \
# 0       Second Class   Consumer        Henderson    Kentucky  South
# 1       Second Class   Consumer        Henderson    Kentucky  South
# 2       Second Class  Corporate      Los Angeles  California   West
# 3     Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4     Standard Class   Consumer  Fort Lauderdale     Florida  South
# ...              ...        ...              ...         ...    ...
# 9989    Second Class   Consumer            Miami     Florida  South
# 9990  Standard Class   Consumer       Costa Mesa  California   West
# 9991  Standard Class   Consumer       Costa Mesa  California   West
# 9992  Standard Class   Consumer       Costa Mesa  California   West
# 9993    Second Class   Consumer      Westminster  California   West
#
#              Category Sub-Category     Sales  Quantity  Discount    Profit
# 0           Furniture    Bookcases  261.9600         2      0.00   41.9136
# ...

# %%
data_con=data.select_dtypes(include=[np.number])

# %%
#BoxPlot

plt.figure(figsize=[12,8])
sns.set(style="whitegrid")
sns.boxplot(x="variable", y="value", data=pd.melt(data_con), width=1, color = 'red')

plt.show()

# %% [raw]
# From the above plot, the outliers im Sales and Profit are clearly seen. As it's a large data set, we can remove those rows containing outliers to improve our results.

# %%
#Removal of Outliers
def remove_outlier(dataset,k=3.33):
    for col in dataset.columns:
            if (dataset[col].dtype=="int64" or dataset[col].dtype=="float64"):
                mean = dataset[col].mean()
                global ds      
                std = dataset[col].std()    
                outlier = [i for i in dataset[col] if (i > mean - k * std)]
                outlier = [i for i in outlier if (i < mean + k * std)]       
                ds = dataset.loc[dataset[col].isin(outlier)]
                

remove_outlier(data,k=3.33)

# %% [raw]
# outliers are removed and out dataset is now ready to Use for Exploratory Analysis.

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize = (20,10))
sns.countplot(data['Ship Mode'])
plt.title("POPULAR SHIPPING MODEL",size = 20)
plt.show()

# %%
#Category wise sales in Each region
plt.figure(figsize=[12,8])
ax = sns.barplot(x="Region", y="Sales", hue="Category", data=ds, palette="Greens")

# %%
#Segment wise count of the ship modes
sns.catplot("Ship Mode", hue="Segment", data=ds, kind="count", aspect=1.5, palette="plasma")

# %%
#Segment wise sales in Each region
plt.figure(figsize=[12,8])
ax = sns.barplot(x="Region", y="Sales", hue="Segment", data=ds, palette="Set1")

# %%
grp = data.groupby('Segment')['Quantity'].sum().reset_index()
grp
# Out:
#        Segment  Quantity
# 0     Consumer     19497
# 1    Corporate     11591
# 2  Home Office      6732

# %%
labels = data['Segment'].unique()
plt.figure(figsize=(8,6))
plt.pie(grp['Quantity'],autopct='%1.1f%%',labels=labels,explode=(0.1,0.1,0),shadow=True,startangle=80)
plt.title('QUANTILIES ORDERED BY EACH SEGMENT',size=25,color = 'GREEN')
plt.show()

# %%
plt.figure(figsize =(20,10))
sns.countplot(data['State'],palette = 'rocket')
plt.xticks(rotation = 90)
plt.show()

# %%
top10_city = data.groupby('City')['Quantity'].sum().reset_index().sort_values(by='Quantity',ascending=False)
top10_city
# Out:
#               City  Quantity
# 329  New York City      3413
# 266    Los Angeles      2876
# 374   Philadelphia      1978
# 438  San Francisco      1920
# 452        Seattle      1578
# ..             ...       ...
# 213      Iowa City         1
# 386    Port Orange         1
# 257    Lindenhurst         1
# 259      Littleton         1
# 140         Elyria         1
#
# [531 rows x 2 columns]

# %%
top10_city.head(10)
# Out:
#               City  Quantity
# 329  New York City      3413
# 266    Los Angeles      2876
# 374   Philadelphia      1978
# 438  San Francisco      1920
# 452        Seattle      1578
# 207        Houston      1460
# 80         Chicago      1129
# 94        Columbus       834
# 437      San Diego       670
# 464    Springfield       649

# %%
plt.figure(figsize = (20,10))
sns.catplot('City','Quantity',data = top10_city.head(10),kind = 'bar',height=8,aspect=2,palette='cividis')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### REGION WISE QUANTITY

# %%
region  = data.groupby('Region')['Quantity'].sum().reset_index()
region
# Out:
#     Region  Quantity
# 0  Central      8768
# 1     East     10609
# 2    South      6209
# 3     West     12234

# %%
labels = data['Region'].unique()
plt.figure(figsize=(8,6))
plt.pie(region['Quantity'],autopct='%1.1f%%',labels=labels,explode=(0.1,0.1,0.05,0.05),shadow=True,startangle=80)
plt.title('QUANTITIES ORDERED BY EACH REGION',size=25,color = 'green')
plt.show()

# %%
cat = data.groupby('Category')['Quantity'].sum().reset_index()
cat
# Out:
#           Category  Quantity
# 0        Furniture      8020
# 1  Office Supplies     22861
# 2       Technology      6939

# %%
labels = data['Category'].unique()
plt.figure(figsize=(8,6))
plt.pie(cat['Quantity'],autopct='%1.1f%%',labels=labels,explode=(0.1,0.1,0.05),shadow=True,startangle=80)
plt.title('DISTRIBUTION OF PRODUCTS SOLD',size=25,color = 'green')
plt.show()

# %%
cat = data.groupby('Category')['Profit'].sum().reset_index()
cat
# Out:
#           Category       Profit
# 0        Furniture   18421.8137
# 1  Office Supplies  122364.6608
# 2       Technology  145454.9481

# %% [markdown]
# ### State wise profit

# %%
#State wise profit
plt.figure(figsize=[24,15])
ax = sns.barplot(x="State", y="Profit", data=ds, palette="Set1",)
plt.xticks(rotation=90, fontsize=16)
plt.yticks(fontsize=15)
plt.title("States VS Profit",fontsize=24)
plt.xlabel("States",fontsize=20)
plt.ylabel("Profit",fontsize=20)
plt.tight_layout()

# %%
labels = data['Category'].unique()
plt.figure(figsize=(8,6))
plt.pie(cat['Profit'],autopct='%1.1f%%',labels=labels,explode=(0.1,0.1,0.05),shadow=True,startangle=80)
plt.title('PROFIT OF ALL CATEGORIES',size=25,color = 'green')
plt.show()

# %% [markdown]
# ### TOP 10 PROFITABLE SELLING ITEMS

# %%
items = data.groupby('Sub-Category')['Profit'].sum().reset_index().sort_values(by = 'Profit',ascending = False)
items.head(10)
# Out:
#    Sub-Category      Profit
# 6       Copiers  55617.8249
# 13       Phones  44515.7306
# 0   Accessories  41936.6357
# 12        Paper  33944.2395
# 3       Binders  30228.0003
# 5        Chairs  26567.1278
# 14      Storage  21278.8264
# 1    Appliances  18138.0054
# 9   Furnishings  13052.7230
# 7     Envelopes   6964.1767

# %%
plt.figure(figsize =(20,10))
sns.catplot('Sub-Category','Profit',data=items.head(10),kind='bar',aspect=2.5,height=8,palette='coolwarm')
plt.title('TOP 10 PROFITABLE PRODUCTS',size=25,color = 'Green')
plt.xticks(size=15)
plt.yticks(size=15)
plt.ylabel('CUMULATIVE PROFIT',size=15)
plt.xlabel('PRODUCTS',size=15)
# Out:
# Text(0.5, 8.913125000000022, 'PRODUCTS')

# %% [markdown]
# ### TOP 10 PROFITABLE CITIES

# %%
city = data.groupby('City')['Profit'].sum().reset_index().sort_values(by = 'Profit',ascending = False)
city.head(10)
# Out:
#               City      Profit
# 329  New York City  62013.8973
# 266    Los Angeles  30431.4267
# 452        Seattle  29121.6825
# 438  San Francisco  17466.1186
# 123        Detroit  13146.6935
# 233      Lafayette  10018.3876
# 215        Jackson   7581.6828
# 21         Atlanta   6993.6629
# 300    Minneapolis   6824.5846
# 437      San Diego   6377.1960

# %%
plt.figure(figsize =(20,10))
sns.catplot('City','Profit',data=city.head(10),kind='bar',aspect=3,height=8,palette='cividis')
plt.title('TOP 10 CITIES WITH PROFITABLE',size=25,color = 'Green')
plt.xticks(size=15)
plt.yticks(size=15)
plt.ylabel('CUMULATIVE PROFIT',size=15)
plt.xlabel('CITY',size=15)
# Out:
# Text(0.5, 8.913125000000022, 'CITY')

# %% [markdown]
# ###### Overall scinerio shows large cities, like New York, Los Angeles, Seatle, San Francisco are generating highest amount of Sales as well as Profit. And in case of Categories, Technology is always leading in terms of Sales and Profit and Furniture is lagging. Products like copiers, Phone, Accessories arew give high cumulative profit. In category 'Technology', subcategory 'Copiers' is having the highest sales. It is ahead in each of the regions. Envelopes is having lowest amount of sales. 'District of Columbia', 'Vermont','Wyoming' states are generating highest profits. And States like 'Texas','Pennsylvania','Illinois','Arizona','Oregon','Colorado','Ohio' are generating losses. Hence focus has to be given in such States.
